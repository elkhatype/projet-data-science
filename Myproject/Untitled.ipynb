# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_sci = pd.read_excel("excel-comp-data (2).xlsx.xlsx",index_col=0)
data_sci.dropna 
print (data_sci)
# Out:
#                    Prenom     Adresse  Moyenne    Age      Région  \
# Nom
# Ahmed           Elkhatype  sacré-cœur    14.50  26ans       Dakar
# Ngom                 Seck  sacré-cœur    15.25  20ans       Dakar
# Couly              Prince  sacré-cœur    11.00  20ans       Dakar
# Imnou              Junior  sacré-cœur    13.00  20ans       Dakar
# Fall              Mohamed       Louga    12.00  20ans       Louga
# Dia                Papito  sacré-cœur    10.99  20ans       Dakar
# Ba                 Malick      Escale    10.90  25ans       Thies
# Ba                 Mojito      Escale    10.00  27ans       Thies
# Diallo          Alexandre      Escale    10.90  30ans       Thies
# Ndour                 Aby      Escale    10.75  25ans       Thies
# Dialou Touré         Absa      Escale    10.50  25ans       Thies
# Dia             haissatou    ST.louis    10.90  25ans    St.Louis
# Diop                Adama    ST.louis    10.25  25ans    St.Louis
# ...

# %%
data_sci = pd.read_excel("lis-elves.xlsx",index_col=0)
data_sci.dropna 
print (data_sci)
# Out:
#                                      Unnamed: 1 Unnamed: 2
# liste des eleves ayant plus de 20ans
# Sankaré                                   Oumou      21ans
# Sow                                         Awa      22ans
# Koné                                     Bakary      22ans
# Seck                                   Mouhamet      22ans
# Kane                                   Mouhamet      22ans
# Keita                                     Salif      22ans
# Samb                                       Aida      23ans
# Sene                                      Diaté      24ans
# Samb                                   maguette      24ans
# Dieye                                   Babacar      24ans
# Diabaye                                     Joe      24ans
# Fall                                    Serigne      24ans
# Ba                                       Malick      25ans
# Ndour                                       Aby      25ans
# ...

# %%
data_sci = pd.read_excel("stat-global.xlsx",index_col=0)
data_sci.dropna
print (data_sci)
# Out:
#                    Prenom     Adresse  Moyenne    Age      Région  \
# Nom
# abdraman            Ndeye        Bour    13.50  20ans       Mbour
# Ahmed           Elkhatype  sacré-cœur    14.50  26ans       Dakar
# Ba                 Malick      Escale    10.90  25ans       Thies
# Ba                 Mojito      Escale    10.00  27ans       Thies
# Ba                   Adji        Yoff    15.00  20ans       Dakar
# Baldé               Keita       tamba    12.00  18ans       Tamba
# Baldé             Djenaba        Yoff    15.00  20ans       Dakar
# Baldé            Aissatou    ST.louis    10.50  25ans    St.Louis
# Couly              Prince  sacré-cœur    11.00  20ans       Dakar
# Dao                   Mor        fass    13.50  27ans       Dakar
# Dia                Papito  sacré-cœur    10.99  20ans       Dakar
# Dia             haissatou    ST.louis    10.90  25ans    St.Louis
# Diabaye               Joe       Kedou    13.50  24ans    Kédougou
# ...
